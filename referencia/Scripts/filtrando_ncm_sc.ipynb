# %%
import polars as pl

# %%
lf = pl.scan_parquet(r'C:\Users\matheus.manzke\Projetos\dados-comex\Dados\gold\comexstat_ncm_all.parquet')

# %%
df_sc = lf.filter(pl.col('sg_uf_ncm') == 'SC').collect()

# %%
df_sc.write_parquet(r'C:\Users\matheus.manzke\Projetos\dados-comex\Dados\gold\comexstat_ncm_sc.parquet')
